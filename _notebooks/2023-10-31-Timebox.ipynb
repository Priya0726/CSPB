# %% [markdown]
# ---
# toc: true
# comments: true
# layout: default
# title: Notes during class
# description: A Place where all my notes and descriptions of my notes that we all collevctively took together as a group are.
# courses: { csp: {week: 13} }
# type: hacks
# ---

# %%
# Python Pseudocode with Detailed Explanations

# Variables and Assignments
name = "Alice"  # Assigning a string to the 'name' variable
age = 25  # Assigning an integer to the 'age' variable
height = 1.75  # Assigning a float to the 'height' variable
is_student = True  # Assigning a boolean value to the 'is_student' variable

# Output
print("Hello, " + name)  # Printing a personalized greeting with the 'name' variable

# Input
user_input = input("Enter your age: ")  # Prompting the user for input and storing it as a string
user_age = int(user_input)  # Converting the input to an integer for calculations

# Conditional Statements
if user_age < 18:
    print("You are a minor.")
elif user_age >= 18 and user_age < 65:
    print("You are an adult.")
else:
    print("You are a senior citizen.")
# The if-elif-else structure checks the user's age and provides different messages accordingly

# Loops
for i in range(1, 6):  # Looping from 1 to 5 (inclusive)
    print("Iteration", i)
# This loop iterates from 1 to 5 and prints each iteration's number

# Lists
fruits = ["apple", "banana", "cherry"]  # Creating a list of strings
fruits.append("date")  # Adding the string "date" to the list
# A list is a collection of items, and 'append' adds an item to the end of the list

# Functions
def greet_person(name):
    print("Hello, " + name)

# Function Call
greet_person("Bob")
# Defining a function to greet a person and calling it with the name "Bob"

# Libraries
import math  # Importing the math library

# Using the math library
square_root = math.sqrt(16)  # Calculating the square root of 16 using a function from the library
# The 'math' library provides mathematical functions, and 'sqrt' calculates the square root

# Dictionaries
person = {"name": "Eve", "age": 30, "city": "Wonderland"}  # Creating a dictionary
print(person["name"])  # Accessing and printing the 'name' value from the dictionary
# A dictionary stores key-value pairs, and you can access values using keys

# API (Application Programming Interface) Usage
# Using an API to fetch weather information
import requests

api_key = "YOUR_API_KEY"
city = "New York"
url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    temperature_celsius = data["current"]["temp_c"]
    print(f"The temperature in {city} is {temperature_celsius}°C.")
else:
    print("Failed to fetch weather data.")
# This code demonstrates making an API request to fetch weather data, parsing the response, and handling success and failure

# Boolean Logic
is_raining = True
has_umbrella = True

if is_raining and not has_umbrella:
    print("You'll get wet!")
# This condition checks if it's raining and you don't have an umbrella, then prints a warning

# Comments
# This is a single-line comment
"""
This is a
multi-line comment
"""
# Comments provide explanations and are not executed as code

# Error Handling
try:
    result = 10 / 0  # Attempting to divide by zero, which raises an exception
except ZeroDivisionError:
    print("Division by zero is not allowed.")
# This code demonstrates error handling using a 'try' and 'except' block

# Data Structures
# Classes and Objects
class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def describe(self):
        print(f"This is a {self.brand} {self.model}.")

my_car = Car("Toyota", "Camry")
my_car.describe()
# Defining a class 'Car,' creating an instance 'my_car,' and calling the 'describe' method
