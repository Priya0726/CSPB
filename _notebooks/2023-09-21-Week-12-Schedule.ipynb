# %% [markdown]
# ---
# toc: true
# comments: false
# layout: post
# title: Week 12 Schedule
# description: My Plan and accomplishments for Week 12
# courses: { csp: {week: 12} }
# type: Plans
# ---

# %%
# This week was the week of Night at the Museum
 '''This week we faced a lot of complications because of our various issues with out Night at the Museum Project
- Our Frontend and our Backend didn't integrate at the last moment and our whole project crashed. 
- We couldn't get our backend to work at all and we decided to switch gears and work on a whole new project that we developed. 
- We are thinking that the prior issue seemed to have been regaurding Flask on the common computer that we were working on.
- Meanwhile the makefile was also not working on multiple of our group members computers. '''

# %%
<!-- In our Night at the Museum Project, I helped with creating one of our main features: the Geography Quiz. To make the quiz I used JavaScript, and HTML. -->

<!DOCTYPE html>
<html>
<head>
  <title>Geography Quiz</title>
</head>
<body>
  <h1>Geography Quiz</h1>
  <script>
    const questions = [
      {
        question: 'What is the capital of France?',
        options: ['Berlin', 'Madrid', 'Rome', 'Paris'],
        correctAnswer: 'Paris',
      },
      {
        question: 'Which river is the longest in the world?',
        options: ['Nile', 'Amazon', 'Yangtze', 'Mississippi'],
        correctAnswer: 'Nile',
      },
      {
        question: 'In which country is the city of Sydney located?',
        options: ['Canada', 'Australia', 'United States', 'South Africa'],
        correctAnswer: 'Australia',
      },
      {
        question: 'What is the largest desert in the world?',
        options: ['Sahara', 'Gobi', 'Arabian', 'Antarctica'],
        correctAnswer: 'Antarctica',
      },
      {
        question: 'Which continent is known as the "Land Down Under"?',
        options: ['Europe', 'Asia', 'Australia', 'South America'],
        correctAnswer: 'Australia',
      },
      {
        question: 'In which country can you find the city of Istanbul?',
        options: ['Greece', 'Turkey', 'Egypt', 'Italy'],
        correctAnswer: 'Turkey',
      },
      {
        question: 'What is the highest mountain in the world?',
        options: ['Mount Kilimanjaro', 'Mount Everest', 'K2', 'Mount Fuji'],
        correctAnswer: 'Mount Everest',
      },
      {
        question: 'Which country is known as the Land of the Rising Sun?',
        options: ['China', 'South Korea', 'Japan', 'Vietnam'],
        correctAnswer: 'Japan',
      },
      {
        question: 'The Panama Canal connects which two bodies of water?',
        options: ['Atlantic Ocean and Mediterranean Sea', 'Pacific Ocean and Red Sea', 'Atlantic Ocean and Indian Ocean', 'Pacific Ocean and Caribbean Sea'],
        correctAnswer: 'Pacific Ocean and Caribbean Sea',
      },
      {
        question: 'Which African country is famous for its pyramids?',
        options: ['Nigeria', 'Sudan', 'Egypt', 'Kenya'],
        correctAnswer: 'Egypt',
      },
    ];

    let score = 0;

    function askQuestion(questionObj) {
      const userAnswer = prompt(questionObj.question + '\n' + questionObj.options.join(', '));
      if (userAnswer === questionObj.correctAnswer) {
        score++;
      }
    }

    for (const question of questions) {
      askQuestion(question);
    }

    alert('Your score: ' + score + '/' + questions.length);
  </script>
</body>
</html>



<!-- This code for the quiz is in HTML and JavaScript. The structure of the quiz is created using HTML while the design is done using CSS/JavaScript  -->

# %%
#This is the same geography quiz that I converted and wrote in Python

questions = [
    {
        "question": "What is the capital of France?",
        "options": ["Berlin", "Madrid", "Rome", "Paris"],
        "correct_answer": "Paris",
    },
    {
        "question": "Which river is the longest in the world?",
        "options": ["Nile", "Amazon", "Yangtze", "Mississippi"],
        "correct_answer": "Nile",
    },
    {
        "question": "In which country is the city of Sydney located?",
        "options": ["Canada", "Australia", "United States", "South Africa"],
        "correct_answer": "Australia",
    },
    {
        "question": "What is the largest desert in the world?",
        "options": ["Sahara", "Gobi", "Arabian", "Antarctica"],
        "correct_answer": "Antarctica",
    },
    {
        "question": 'Which continent is known as the "Land Down Under"?',
        "options": ["Europe", "Asia", "Australia", "South America"],
        "correct_answer": "Australia",
    },
    {
        "question": "In which country can you find the city of Istanbul?",
        "options": ["Greece", "Turkey", "Egypt", "Italy"],
        "correct_answer": "Turkey",
    },
    {
        "question": "What is the highest mountain in the world?",
        "options": ["Mount Kilimanjaro", "Mount Everest", "K2", "Mount Fuji"],
        "correct_answer": "Mount Everest",
    },
    {
        "question": 'Which country is known as the "Land of the Rising Sun"?',
        "options": ["China", "South Korea", "Japan", "Vietnam"],
        "correct_answer": "Japan",
    },
    {
        "question": "The Panama Canal connects which two bodies of water?",
        "options": ["Atlantic Ocean and Mediterranean Sea", "Pacific Ocean and Red Sea", "Atlantic Ocean and Indian Ocean", "Pacific Ocean and Caribbean Sea"],
        "correct_answer": "Pacific Ocean and Caribbean Sea",
    },
    {
        "question": "Which African country is famous for its pyramids?",
        "options": ["Nigeria", "Sudan", "Egypt", "Kenya"],
        "correct_answer": "Egypt",
    },
]

score = 0

for question in questions:
    print(question["question"])
    for i, option in enumerate(question["options"]):
        print(f"{i + 1}. {option}")
    
    user_answer = input("Enter the number of your answer: ")
    user_answer = int(user_answer) - 1  # Adjust for 0-based indexing
    
    if user_answer >= 0 and user_answer < len(question["options"]) and question["options"][user_answer] == question["correct_answer"]:
        score += 1

print(f"Your score: {score}/{len(questions)}")


'''It defines a list of questions, each represented as a dictionary with a question, answer options, and the correct answer.
    - It initializes a variable score to keep track of the user's score.
    - It uses a for loop to iterate through each question in the list.
    - For each question, it displays the question and answer options, allowing the user to input their answer as a number.
    - It checks if the user's answer is valid and matches the correct answer. If so, it increments the user's score.
    - After all questions have been answered, it displays the user's final score.
This code provides a basic framework for creating and running a text-based quiz and can be extended or customized for different quizzes.'''

# %%
# Based on what I learned with the Night at the Museum Project, I understood that it really important to commit the code so that you can more easily collaborate with your group.
# I also think that I have to work on
